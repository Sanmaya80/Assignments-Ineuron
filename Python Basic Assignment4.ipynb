# %%
1. What exactly is []?

Ans- [] is empty list or we can say List with no data in it.

# %%
2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

ANS- spam=[2,4,6,8,10]
Spam[2]=”hello”

# %%
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %%
3. What is the value of spam[int(int('3' * 2) / 11)]?

Ans- The value of spam[int(int('3' * 2) / 11)] is d

# %%
4. What is the value of spam[-1]?

Ans- The Value of spam[-1] is d

# %%
5. What is the value of spam[:2]?

Ans- the value of spam[:2] is [‘a’,’ b’]

# %%
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
6. What is the value of bacon.index('cat')?

Ans- bacon.index(‘cat’) will the value of 1

# %%
7. How does bacon.append(99) change the look of the list value in bacon?

Ans- bacon.append(99) change the look of the list value as [3.14, 'cat', 11, 'cat', True, 99]

# %%
8. How does bacon.remove('cat') change the look of the list meaning in bacon?

Ans- bacon.remove(‘cat’) will change the look of the list meaning as [3.14, 11, 'cat', True, 99]

# %%
9. What are the list concatenation and list replication operators?

Ans- we can concatenate list with + operator while for list replication we use * operator

# %%
10. What is difference between the list methods append() and insert()?

Ans- The append() method add a value to the last position in list while insert() methos add value to a given position.

# %%
11. What are the two methods for removing items from a list?

Ans- the two methods for removing items from a list are del  and remove()

# %%
12. Describe how list values and string values are identical.

Ans- All functions and methods are applicable to list and string but list are mutable where as string are not.

# %%
13.What's the difference between tuples and lists?

Ans-Tuples are List are variable which store values in one location, but list are mutable and tuples are not

# %%
14. How do you type a tuple value that only contains the integer 42?

Ans-(42,)

# %%
15. How do you get a list value's tuple form? How do you get a tuple value's list form?

Ans- by using the tuple(listname) and list(tuplename) we can get a list value's tuple form and tuple value's list form

# %%
16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

Ans- Variables that "contain" list values are not necessarily lists themselves, they contain reference to the values.

# %%
17. How do you distinguish between copy.copy() and copy.deepcopy()?

Ans- copy.copy() method will create a shallow copy of a list and copy.deepcopy() will create a deep copy of list .
