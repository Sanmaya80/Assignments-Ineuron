# %%
my_list=[]
my_list=[1,2,3]
my_list=[1,"Hello",3.4]

# %%
my_list=["mouse",[8,4,6],['a']]
my_list=['p','r','o','b','e']
print(my_list[0])
# Out:
# p

# %%
print(my_list[4])
# Out:
# e

# %%
n_list=["Happy",[2,0,1,5]]

# %%
print(n_list[1][3])
# Out:
# 5

# %%
odd=[2,4,6,8]
print(odd)
# Out:
# [2, 4, 6, 8]

# %%
odd[1:4]=[3,5,7]

# %%
print(odd)
# Out:
# [2, 3, 5, 7]

# %%
odd=[1,3,5]
odd.append(7)

# %%
odd
# Out:
# [1, 3, 5, 7]

# %%
odd.extend([9,11,13])

# %%
odd
# Out:
# [1, 3, 5, 7, 9, 11, 13]

# %%
odd=[1,3,5]
print(odd+[9,7,5])
# Out:
# [1, 3, 5, 9, 7, 5]

# %%
print(["re"] * 3)
# Out:
# ['re', 're', 're']

# %%
odd=[1,9]

# %%
odd.insert(1,3)

# %%
vowels=['a','e','i','o','u']
index=vowels.index('e')

# %%
print(index)
# Out:
# 1

# %%
my_tuple=(4,2,3,[6,5])

# %%
my_tuple[3][0]=9
my_tuple
# Out:
# (4, 2, 3, [9, 5])

# %%
my_tuple=('p','r'.'o','g','r','a','m','i','z')
# Out:
#   File "<ipython-input-27-8b814d733fb1>", line 1
#     my_tuple=('p','r'.'o','g','r','a','m','i','z')
#                         ^
# SyntaxError: invalid syntax

# %%
print(my_tuple)
# Out:
# (4, 2, 3, [9, 5])

# %%
my_tuple=('a','p','p','l','e')
my_tuple.index('p')
# Out:
# 1

# %% [markdown]
# # SETS

# %%
my_set={1,2}
print(my_set)
# Out:
# {1, 2}

# %%
my_set.add(3)
print(my_set)
# Out:
# {1, 2, 3}

# %%
my_set.update([4,5,6])
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set.update([4,5],{1,6,8})
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
my_set={1,3,4,5,6}
print(my_set)
# Out:
# {1, 3, 4, 5, 6}

# %%
my_set.discard(4)
print(my_set)
# Out:
# {1, 3, 5, 6}

# %%
my_set.remove(6)
print(my_set)
# Out:
# {1, 3, 5}
