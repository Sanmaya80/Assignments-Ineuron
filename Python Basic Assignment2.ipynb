# %%
1. What are the Boolean data type's two values? How do you go about writing them?

Ans- the Boolean Data types are True and False.
We can write them as True and False

# %%
2. What are the three different types of Boolean operators?

Ans- The three different types of Boolean Operators are comparison operators, binary Boolean operators and Not Operator

# %%
3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

Ans   True or False = True
         False or True= True
         True or True=True
         False or False=False
         True and False= False
          False and True= False
          True and True=True
          False and False=False

# %%
4. What are the values of the following expressions?

(5 > 4) and (3 == 5) = False
not (5 > 4) = False
(5 > 4) or (3 == 5) = True
not ((5 > 4) or (3 == 5)) = False
(True and True) and (True == False) = True
(not False) or (not True) =True

# %%
5. What are the six different types of reference operators?

Ans- the six different types of operators are 
Arithmatic Operator
Logical Operator
Bitwise Operator
Relational Operator
Assigment Operator
Membership Operator

# %%
6. How do you tell the difference between the equal to and assignment operators?

Ans – In Python the equal to operator is == while the assignment Operator is = .

# %%
7. Describe a condition and when you would use one.

Ans- Condition is a expression, we use condition to take decision.

# %%
8. Recognize the following three blocks in this code:

spam = 0
if spam == 10:
    print('eggs')
    if spam > 5:
        print('bacon')
    else:
        print('ham')
    print('spam')
print('spam')


ANS-
This code will print Spam as the initial if statement evaluation is false hence the code will print the last print statement by skipping the if and nested if statements.

# %%
9. Create a programme that prints. If 1 is stored in spam, prints Hello; if 2 is stored in spam, prints Howdy; and if 3 is stored in spam, prints Salutations! if there's something else in spam.

Ans-
spam=3
if spam==1:
    print('Hello')
elif spam==2:
    print('Howdy')
elif spam==3:
    print('Salutation!')
else:
    print(" ")

# %%
10.If your programme is stuck in an endless loop, what keys can you press?

Control + Shift + delete

# %%
11. How can you tell the difference between break and continue?

Ans- by Break statement we can terminate the loop before it has loop through all items.
With Continue we can stop the current iteration of the loop  and continue with the next .

# %%
12. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

Ans- in a for loop there is no difference between range(10), range(0,10) and range(0,10,1)
