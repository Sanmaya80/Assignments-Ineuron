# %%
1. What are the differences between operators and values in the following?

*              is multiplication Operator
'hello'     is a value of string data type
-87.8       is a negative value float data type
-              is subtract/difference operator
/              is division operator
+             is plus or addition Operator
6             is a value of integer data type

# %%
2. What is the difference between string and variable?

 Spam is a variable as in not surrounded by quotes
'spam' is string variable as is surrounded by quotes

# %%
3. Describe three different data forms.

The three data form are integer, string, float

# %%
4. What makes up an expression? What are the functions of all expressions?
Ans-
Expressions are representation of value. The function of all expression is to evaluate a value

# %%
5. In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?
Ans-
Spam=10 is an assignment statement because here we are assigning a value 10 to the variable Spam. Where as  int spam is the declaration of integer type variable spam which can integer data type.

# %%
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
 Ans- The Variable bacon contain 22

# %%
7. What should the values of the following two terms be?

'spam' + 'spamspam'
'spam' * 3

Ans-  The value of 'spam' + 'spamspam' wil be ‘spamspamspam’
‘spam’*3 value would be ‘spamspamspam’

# %%
8. Why is it that eggs is a true variable name but 100 is not?

Ans – Variable name always should start with a letter or underscore , hence eggs is true variable and 100 is not.

# %%
9. Which of the following three functions may be used to convert a value to an integer, a floating-point number, or a string?

Ans- the function int() use to convert a value to an integer.
The function float() use to convert a value to an float.
The function str() use to convert a value to an String.

# %%
10. What is the error caused by this expression? What would you do about it?

'I have eaten ' + 99 + ' burritos.'

Ans – 99 is an integer type data  hence it is showing error while concatenating with string type data. We can fix this by converting 99 to string data type like
‘I have eaten’ +str(99)+’burritos’
